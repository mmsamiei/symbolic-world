# %%
import torch
from torch.utils.data import Dataset, IterableDataset, DataLoader
import torch.nn as nn
import random
import numpy as np
import math
from tqdm.auto import tqdm
import torchmetrics

# %%
experiment_config = {
    'obj_size': 4,
    'obs_size': 8,
}
model_config = {
    'd_model': 32,
    'dim_feedforward': 64,
    'n_head': 8,
    'num_layers': 1,
    'num_obj': 8,
}
training_config = {
    'batch_size':512,
    'lr': 5e-5,
    'max_step': 20000
}

# %%
device = torch.device('cuda')

# %%
class SymbolicWorldIterableDataset(IterableDataset):

    def __init__(self, num_objects=4, observation_size=8):
        self.num_objects = num_objects
        self.observation_size = observation_size
        pass

    def generate_observation(self):
        observation = torch.randint(0, self.num_objects, (self.observation_size,))
        parity_1 = ((observation == 1).sum())%2
        return {'observation':observation, 'parity_1':parity_1}

    def __iter__(self):
        while(True):
            yield self.generate_observation()

iterable_dataset = SymbolicWorldIterableDataset(experiment_config['obj_size'], experiment_config['obs_size'])
loader = DataLoader(iterable_dataset, batch_size=training_config['batch_size'])

test_loaders_list = []
for observation_size in [4,8,16,32,64]:
    test_loader_name = f'observation_size_{observation_size}'
    test_loader_data = DataLoader(SymbolicWorldIterableDataset(observation_size=observation_size, num_objects=experiment_config['obj_size']),\
        batch_size=training_config['batch_size'])
    test_loaders_list.append({
        'name': test_loader_name,
        'data_loader': test_loader_data
    })

if True:
    for a in loader:
        print(a['observation'][0])
        print(a['parity_1'][0])
        break
# Out:
# tensor([0, 3, 1, 0, 3, 3, 2, 2])
# tensor(1)

# %%
class MySimpleModel(nn.Module):
    
    def __init__(self, model_config):
        super(MySimpleModel, self).__init__()
        d_model = model_config['d_model']
        n_heads = model_config['n_head']
        n_layers = model_config['num_layers']
        n_objects = model_config['num_obj']
        n_clss = 5
        self.d_model = d_model
        self.encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=n_heads, batch_first=True)
        self.transformer_layer = torch.nn.TransformerEncoder(self.encoder_layer, n_layers)
        self.token_embedding = torch.nn.Embedding(n_objects, d_model)
        self.clss_embedding = torch.nn.Embedding(n_clss, d_model)
        self.fc1 = torch.nn.Linear(d_model, 2)
        
    def forward(self, x, clss):
        '''
        x : long tensor: [batch, seq_len]
        clss: long tensor: [batch, 1]
        return: tensor: [batch, 2]
        '''
        temp = x
        temp = self.token_embedding(temp)
        clss_embedding = self.clss_embedding(clss)
        temp = torch.cat((clss_embedding, temp), dim=1)
        temp = self.transformer_layer(temp)
        temp = temp[:, 0, :]
        temp = self.fc1(temp)
        return temp

# %%
model = MySimpleModel(model_config).to(device)
loss_module = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=training_config['lr'])
f1_module = torchmetrics.F1Score(num_classes=2).to(device)

# %%
def eval(test_loader):
    with torch.no_grad():
            test_f1s = []
            for j, batch in enumerate(test_loader):
                x = batch['observation'].to(device)
                clss = torch.ones((x.shape[0], 1)).long().to(device)
                y = batch['parity_1'].to(device)
                output = model(x, clss)
                preds = output.argmax(dim=1)
                test_f1s.append(f1_module(preds, y).item())
                if j > 10:
                    break
            f1 = sum(test_f1s)/len(test_f1s)
            return round(f1, 4)

# %%
loss_history = []
max_steps = training_config['max_step']
log_every_steps = 200
for i, batch in tqdm(enumerate(loader), total=max_steps):
    x = batch['observation'].to(device)
    clss = torch.ones((x.shape[0], 1)).long().to(device)
    y = batch['parity_1'].to(device)
    optimizer.zero_grad()
    output = model(x, clss)
    loss = loss_module(output, y)
    loss_history.append(loss.item())
    loss.backward()
    optimizer.step()
    if i > max_steps:
        break
    if i % log_every_steps == 0 :
        print("step {}".format(i))
        print("loss: {:.2e}".format(sum(loss_history)/len(loss_history)))
        loss_history = []
        train_f1 = f1_module(output.argmax(dim=1), y).item()
        print('train f1: ', round(train_f1,4))
        for test_loader in test_loaders_list:
            test_acc = eval(test_loader['data_loader'])
            print(test_loader['name'], " f1_score: " , test_acc)
        print('------------------------')
# Out:
#   0%|          | 0/30000 [00:00<?, ?it/s]
# step 0
# loss: 8.37e-01
# train f1:  0.4717
# observation_size_4  f1_score:  0.5031
# observation_size_8  f1_score:  0.501
# observation_size_16  f1_score:  0.5008
# observation_size_32  f1_score:  0.502
# observation_size_64  f1_score:  0.498
# ------------------------
# step 200
# loss: 6.90e-01
# train f1:  0.6309
# observation_size_4  f1_score:  0.6
# observation_size_8  f1_score:  0.6694
# observation_size_16  f1_score:  0.4689
# observation_size_32  f1_score:  0.5014
# observation_size_64  f1_score:  0.5012
# ------------------------
# step 400
# loss: 1.40e-01
# train f1:  0.9775
# observation_size_4  f1_score:  0.6627
# observation_size_8  f1_score:  0.9762
# observation_size_16  f1_score:  0.4564
# observation_size_32  f1_score:  0.4682
# observation_size_64  f1_score:  0.4983
# ------------------------
# step 600
# loss: 2.59e-02
# train f1:  0.9961
# observation_size_4  f1_score:  0.6031
# observation_size_8  f1_score:  0.9967
# observation_size_16  f1_score:  0.5096
# observation_size_32  f1_score:  0.464
# observation_size_64  f1_score:  0.5292
# ------------------------
# step 800
# loss: 1.57e-02
# train f1:  0.9961
# observation_size_4  f1_score:  0.6418
# observation_size_8  f1_score:  0.996
# observation_size_16  f1_score:  0.4759
# observation_size_32  f1_score:  0.4687
# observation_size_64  f1_score:  0.4944
# ------------------------
# step 1000
# loss: 1.44e-02
# train f1:  0.9951
# observation_size_4  f1_score:  0.6822
# observation_size_8  f1_score:  0.9967
# observation_size_16  f1_score:  0.5145
# observation_size_32  f1_score:  0.4885
# observation_size_64  f1_score:  0.5174
# ------------------------
# step 1200
# loss: 1.17e-02
# train f1:  0.9971
# observation_size_4  f1_score:  0.6042
# observation_size_8  f1_score:  0.997
# observation_size_16  f1_score:  0.5018
# observation_size_32  f1_score:  0.449
# observation_size_64  f1_score:  0.5247
# ------------------------
# step 1400
# loss: 4.73e-03
# train f1:  0.999
# observation_size_4  f1_score:  0.5802
# observation_size_8  f1_score:  0.9997
# observation_size_16  f1_score:  0.5088
# observation_size_32  f1_score:  0.4435
# observation_size_64  f1_score:  0.5316
# ------------------------
# step 1600
# loss: 3.17e-03
# train f1:  1.0
# observation_size_4  f1_score:  0.5986
# observation_size_8  f1_score:  0.9994
# observation_size_16  f1_score:  0.4289
# observation_size_32  f1_score:  0.4779
# observation_size_64  f1_score:  0.4823
# ------------------------
# step 1800
# loss: 2.53e-03
# train f1:  1.0
# observation_size_4  f1_score:  0.5911
# observation_size_8  f1_score:  0.9996
# observation_size_16  f1_score:  0.5108
# observation_size_32  f1_score:  0.4716
# observation_size_64  f1_score:  0.5161
# ------------------------
# step 2000
# loss: 2.59e-03
# train f1:  1.0
# observation_size_4  f1_score:  0.6594
# observation_size_8  f1_score:  0.9995
# observation_size_16  f1_score:  0.5033
# observation_size_32  f1_score:  0.4815
# observation_size_64  f1_score:  0.4994
# ------------------------
# step 2200
# loss: 2.42e-03
# train f1:  0.999
# observation_size_4  f1_score:  0.6057
# observation_size_8  f1_score:  0.9995
# observation_size_16  f1_score:  0.5025
# observation_size_32  f1_score:  0.4754
# observation_size_64  f1_score:  0.5181
# ------------------------
# step 2400
# loss: 2.14e-03
# train f1:  1.0
# observation_size_4  f1_score:  0.5683
# observation_size_8  f1_score:  0.9991
# observation_size_16  f1_score:  0.5098
# observation_size_32  f1_score:  0.4633
# observation_size_64  f1_score:  0.53
# ------------------------
# step 2600
# loss: 4.70e-03
# train f1:  1.0
# observation_size_4  f1_score:  0.4958
# observation_size_8  f1_score:  0.9994
# observation_size_16  f1_score:  0.5597
# observation_size_32  f1_score:  0.4496
# observation_size_64  f1_score:  0.5046
# ------------------------
# step 2800
# loss: 2.17e-03
# train f1:  1.0
# observation_size_4  f1_score:  0.5511
# observation_size_8  f1_score:  0.9997
# observation_size_16  f1_score:  0.5238
# observation_size_32  f1_score:  0.4686
# observation_size_64  f1_score:  0.5282
# ------------------------
# step 3000
# loss: 1.86e-03
# train f1:  0.999
# observation_size_4  f1_score:  0.5559
# observation_size_8  f1_score:  0.9995
# observation_size_16  f1_score:  0.5243
# observation_size_32  f1_score:  0.48
# observation_size_64  f1_score:  0.5209
# ------------------------
# step 3200
# loss: 1.85e-03
# train f1:  0.999
# observation_size_4  f1_score:  0.5828
# observation_size_8  f1_score:  0.9999
# observation_size_16  f1_score:  0.5186
# observation_size_32  f1_score:  0.4789
# observation_size_64  f1_score:  0.5184
# ------------------------
# step 3400
# loss: 1.55e-03
# train f1:  0.999
# observation_size_4  f1_score:  0.5681
# observation_size_8  f1_score:  0.9995
# observation_size_16  f1_score:  0.5236
# observation_size_32  f1_score:  0.4929
# observation_size_64  f1_score:  0.5204
# ------------------------
# step 3600
# loss: 1.36e-03
# train f1:  0.999
# observation_size_4  f1_score:  0.5614
# observation_size_8  f1_score:  0.9997
# observation_size_16  f1_score:  0.5269
# observation_size_32  f1_score:  0.4736
# observation_size_64  f1_score:  0.5286
# ------------------------
# step 3800
# loss: 1.08e-03
# train f1:  1.0
# observation_size_4  f1_score:  0.5434
# observation_size_8  f1_score:  0.9995
# observation_size_16  f1_score:  0.5331
# observation_size_32  f1_score:  0.4653
# observation_size_64  f1_score:  0.5239
# ------------------------
# step 4000
# loss: 9.75e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5699
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5422
# observation_size_32  f1_score:  0.4849
# observation_size_64  f1_score:  0.5114
# ------------------------
# step 4200
# loss: 7.03e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5422
# observation_size_8  f1_score:  0.9999
# observation_size_16  f1_score:  0.5418
# observation_size_32  f1_score:  0.5337
# observation_size_64  f1_score:  0.4643
# ------------------------
# step 4400
# loss: 7.18e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.6141
# observation_size_8  f1_score:  0.9998
# observation_size_16  f1_score:  0.5561
# observation_size_32  f1_score:  0.4765
# observation_size_64  f1_score:  0.5332
# ------------------------
# step 4600
# loss: 6.70e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5593
# observation_size_8  f1_score:  0.9998
# observation_size_16  f1_score:  0.5255
# observation_size_32  f1_score:  0.4771
# observation_size_64  f1_score:  0.5202
# ------------------------
# step 4800
# loss: 3.68e-04
# train f1:  0.999
# observation_size_4  f1_score:  0.5588
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5736
# observation_size_32  f1_score:  0.5864
# observation_size_64  f1_score:  0.4653
# ------------------------
# step 5000
# loss: 8.84e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5953
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.498
# observation_size_32  f1_score:  0.4803
# observation_size_64  f1_score:  0.4867
# ------------------------
# step 5200
# loss: 3.85e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5926
# observation_size_8  f1_score:  0.9998
# observation_size_16  f1_score:  0.5055
# observation_size_32  f1_score:  0.4792
# observation_size_64  f1_score:  0.5107
# ------------------------
# step 5400
# loss: 2.77e-04
# train f1:  0.999
# observation_size_4  f1_score:  0.5955
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.4951
# observation_size_32  f1_score:  0.4847
# observation_size_64  f1_score:  0.4843
# ------------------------
# step 5600
# loss: 4.03e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5452
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.526
# observation_size_32  f1_score:  0.4535
# observation_size_64  f1_score:  0.5155
# ------------------------
# step 5800
# loss: 5.46e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.6269
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5635
# observation_size_32  f1_score:  0.4694
# observation_size_64  f1_score:  0.5248
# ------------------------
# step 6000
# loss: 2.52e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5824
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5426
# observation_size_32  f1_score:  0.4873
# observation_size_64  f1_score:  0.517
# ------------------------
# step 6200
# loss: 1.54e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5784
# observation_size_8  f1_score:  0.9999
# observation_size_16  f1_score:  0.5436
# observation_size_32  f1_score:  0.4817
# observation_size_64  f1_score:  0.5162
# ------------------------
# step 6400
# loss: 1.99e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5563
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5352
# observation_size_32  f1_score:  0.4862
# observation_size_64  f1_score:  0.5211
# ------------------------
# step 6600
# loss: 2.13e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5531
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5364
# observation_size_32  f1_score:  0.4666
# observation_size_64  f1_score:  0.5211
# ------------------------
# step 6800
# loss: 2.91e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5898
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5398
# observation_size_32  f1_score:  0.4996
# observation_size_64  f1_score:  0.5028
# ------------------------
# step 7000
# loss: 1.14e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5764
# observation_size_8  f1_score:  0.9999
# observation_size_16  f1_score:  0.5285
# observation_size_32  f1_score:  0.4985
# observation_size_64  f1_score:  0.509
# ------------------------
# step 7200
# loss: 1.27e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5746
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5454
# observation_size_32  f1_score:  0.4795
# observation_size_64  f1_score:  0.5184
# ------------------------
# step 7400
# loss: 2.09e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.564
# observation_size_8  f1_score:  0.9999
# observation_size_16  f1_score:  0.5552
# observation_size_32  f1_score:  0.4935
# observation_size_64  f1_score:  0.5119
# ------------------------
# step 7600
# loss: 1.43e-03
# train f1:  1.0
# observation_size_4  f1_score:  0.5277
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5406
# observation_size_32  f1_score:  0.5238
# observation_size_64  f1_score:  0.4657
# ------------------------
# step 7800
# loss: 2.12e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5396
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5517
# observation_size_32  f1_score:  0.464
# observation_size_64  f1_score:  0.5204
# ------------------------
# step 8000
# loss: 1.77e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5283
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5409
# observation_size_32  f1_score:  0.4582
# observation_size_64  f1_score:  0.5206
# ------------------------
# step 8200
# loss: 1.28e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5455
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5553
# observation_size_32  f1_score:  0.4791
# observation_size_64  f1_score:  0.5235
# ------------------------
# step 8400
# loss: 6.58e-05
# train f1:  1.0
# observation_size_4  f1_score:  0.5359
# observation_size_8  f1_score:  0.9999
# observation_size_16  f1_score:  0.5474
# observation_size_32  f1_score:  0.482
# observation_size_64  f1_score:  0.5304
# ------------------------
# step 8600
# loss: 1.63e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5403
# observation_size_8  f1_score:  0.9999
# observation_size_16  f1_score:  0.5334
# observation_size_32  f1_score:  0.4731
# observation_size_64  f1_score:  0.5194
# ------------------------
# step 8800
# loss: 5.50e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5248
# observation_size_8  f1_score:  0.9996
# observation_size_16  f1_score:  0.5212
# observation_size_32  f1_score:  0.4889
# observation_size_64  f1_score:  0.4892
# ------------------------
# step 9000
# loss: 1.96e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.573
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5592
# observation_size_32  f1_score:  0.4766
# observation_size_64  f1_score:  0.5155
# ------------------------
# step 9200
# loss: 2.21e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5723
# observation_size_8  f1_score:  0.9998
# observation_size_16  f1_score:  0.5459
# observation_size_32  f1_score:  0.4824
# observation_size_64  f1_score:  0.5217
# ------------------------
# step 9400
# loss: 2.51e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5619
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5424
# observation_size_32  f1_score:  0.4836
# observation_size_64  f1_score:  0.5108
# ------------------------
# step 9600
# loss: 6.87e-05
# train f1:  1.0
# observation_size_4  f1_score:  0.5735
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5442
# observation_size_32  f1_score:  0.4848
# observation_size_64  f1_score:  0.5229
# ------------------------
# step 9800
# loss: 1.26e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5669
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5458
# observation_size_32  f1_score:  0.4781
# observation_size_64  f1_score:  0.5201
# ------------------------
# step 10000
# loss: 1.46e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.554
# observation_size_8  f1_score:  0.9998
# observation_size_16  f1_score:  0.5448
# observation_size_32  f1_score:  0.4817
# observation_size_64  f1_score:  0.5165
# ------------------------
# step 10200
# loss: 9.42e-05
# train f1:  1.0
# observation_size_4  f1_score:  0.5357
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5548
# observation_size_32  f1_score:  0.4867
# observation_size_64  f1_score:  0.5194
# ------------------------
# step 10400
# loss: 1.74e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5504
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5467
# observation_size_32  f1_score:  0.4661
# observation_size_64  f1_score:  0.5268
# ------------------------
# step 10600
# loss: 7.81e-05
# train f1:  1.0
# observation_size_4  f1_score:  0.5468
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5378
# observation_size_32  f1_score:  0.4718
# observation_size_64  f1_score:  0.5174
# ------------------------
# step 10800
# loss: 7.34e-05
# train f1:  1.0
# observation_size_4  f1_score:  0.541
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5478
# observation_size_32  f1_score:  0.4714
# observation_size_64  f1_score:  0.5168
# ------------------------
# step 11000
# loss: 3.76e-05
# train f1:  1.0
# observation_size_4  f1_score:  0.5366
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5512
# observation_size_32  f1_score:  0.4639
# observation_size_64  f1_score:  0.5259
# ------------------------
# step 11200
# loss: 7.63e-05
# train f1:  1.0
# observation_size_4  f1_score:  0.5598
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5421
# observation_size_32  f1_score:  0.477
# observation_size_64  f1_score:  0.5339
# ------------------------
# step 11400
# loss: 1.13e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5422
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5505
# observation_size_32  f1_score:  0.4787
# observation_size_64  f1_score:  0.5162
# ------------------------
# step 11600
# loss: 8.94e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5645
# observation_size_8  f1_score:  0.9999
# observation_size_16  f1_score:  0.5683
# observation_size_32  f1_score:  0.473
# observation_size_64  f1_score:  0.5133
# ------------------------
# step 11800
# loss: 2.18e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5502
# observation_size_8  f1_score:  0.9999
# observation_size_16  f1_score:  0.5469
# observation_size_32  f1_score:  0.4784
# observation_size_64  f1_score:  0.5228
# ------------------------
# step 12000
# loss: 7.44e-05
# train f1:  1.0
# observation_size_4  f1_score:  0.5439
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5444
# observation_size_32  f1_score:  0.4869
# observation_size_64  f1_score:  0.5231
# ------------------------
# step 12200
# loss: 1.35e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5452
# observation_size_8  f1_score:  0.9999
# observation_size_16  f1_score:  0.5334
# observation_size_32  f1_score:  0.4823
# observation_size_64  f1_score:  0.5214
# ------------------------
# step 12400
# loss: 4.71e-05
# train f1:  1.0
# observation_size_4  f1_score:  0.5598
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5478
# observation_size_32  f1_score:  0.481
# observation_size_64  f1_score:  0.525
# ------------------------
# step 12600
# loss: 7.48e-05
# train f1:  1.0
# observation_size_4  f1_score:  0.5409
# observation_size_8  f1_score:  0.9999
# observation_size_16  f1_score:  0.5493
# observation_size_32  f1_score:  0.4792
# observation_size_64  f1_score:  0.5287
# ------------------------
# step 12800
# loss: 8.67e-05
# train f1:  1.0
# observation_size_4  f1_score:  0.55
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5396
# observation_size_32  f1_score:  0.4852
# observation_size_64  f1_score:  0.5297
# ------------------------
# step 13000
# loss: 7.75e-05
# train f1:  1.0
# observation_size_4  f1_score:  0.547
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5442
# observation_size_32  f1_score:  0.4803
# observation_size_64  f1_score:  0.5247
# ------------------------
# step 13200
# loss: 5.56e-05
# train f1:  1.0
# observation_size_4  f1_score:  0.554
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.5519
# observation_size_32  f1_score:  0.4792
# observation_size_64  f1_score:  0.5241
# ------------------------
# step 13400
# loss: 8.52e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5908
# observation_size_8  f1_score:  0.9999
# observation_size_16  f1_score:  0.4407
# observation_size_32  f1_score:  0.4952
# observation_size_64  f1_score:  0.4506
# ------------------------
# step 13600
# loss: 9.98e-05
# train f1:  1.0
# observation_size_4  f1_score:  0.5592
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.4644
# observation_size_32  f1_score:  0.4823
# observation_size_64  f1_score:  0.4657
# ------------------------
# step 13800
# loss: 1.85e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5802
# observation_size_8  f1_score:  0.9999
# observation_size_16  f1_score:  0.5487
# observation_size_32  f1_score:  0.462
# observation_size_64  f1_score:  0.5074
# ------------------------
# step 14000
# loss: 3.82e-04
# train f1:  1.0
# observation_size_4  f1_score:  0.5203
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.4316
# observation_size_32  f1_score:  0.4493
# observation_size_64  f1_score:  0.4801
# ------------------------
# step 14200
# loss: 9.07e-05
# train f1:  1.0
# observation_size_4  f1_score:  0.5193
# observation_size_8  f1_score:  1.0
# observation_size_16  f1_score:  0.4409
# observation_size_32  f1_score:  0.4378
# observation_size_64  f1_score:  0.4859
# ------------------------
# step 14400
# loss: 8.38e-05
# train f1:  1.0
# observation_size_4  f1_score:  0.5141
# observation_size_8  f1_score:  1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/mmsamiei/symbolic-world/parity.ipynb Cell 8' in <cell line: 4>()
#      <a href='vscode-notebook-cell://ssh-remote%2B192.168.198.96/home/mmsamiei/symbolic-world/parity.ipynb#ch0000006vscode-remote?line=20'>21</a> print('train f1: ', round(train_f1,4))
#      <a href='vscode-notebook-cell://ssh-remote%2B192.168.198.96/home/mmsamiei/symbolic-world/parity.ipynb#ch0000006vscode-remote?line=21'>22</a> for test_loader in test_loaders_list:
# ---> <a href='vscode-notebook-cell://ssh-remote%2B192.168.198.96/home/mmsamiei/symbolic-world/parity.ipynb#ch0000006vscode-remote?line=22'>23</a>     test_acc = eval(test_loader['data_loader'])
#      <a href='vscode-notebook-cell://ssh-remote%2B192.168.198.96/home/mmsamiei/symbolic-world/parity.ipynb#ch0000006vscode-remote?line=23'>24</a>     print(test_loader['name'], " f1_score: " , test_acc)
#      <a href='vscode-notebook-cell://ssh-remote%2B192.168.198.96/home/mmsamiei/symbolic-world/parity.ipynb#ch0000006vscode-remote?line=24'>25</a> print('------------------------')
#
# /home/mmsamiei/symbolic-world/parity.ipynb Cell 7' in eval(test_loader)
#       <a href='vscode-notebook-cell://ssh-remote%2B192.168.198.96/home/mmsamiei/symbolic-world/parity.ipynb#ch0000005vscode-remote?line=5'>6</a> clss = torch.ones((x.shape[0], 1)).long().to(device)
#       <a href='vscode-notebook-cell://ssh-remote%2B192.168.198.96/home/mmsamiei/symbolic-world/parity.ipynb#ch0000005vscode-remote?line=6'>7</a> y = batch['parity_1'].to(device)
# ----> <a href='vscode-notebook-cell://ssh-remote%2B192.168.198.96/home/mmsamiei/symbolic-world/parity.ipynb#ch0000005vscode-remote?line=7'>8</a> output = model(x, clss)
#       <a href='vscode-notebook-cell://ssh-remote%2B192.168.198.96/home/mmsamiei/symbolic-world/parity.ipynb#ch0000005vscode-remote?line=8'>9</a> preds = output.argmax(dim=1)
#      <a href='vscode-notebook-cell://ssh-remote%2B192.168.198.96/home/mmsamiei/symbolic-world/parity.ipynb#ch0000005vscode-remote?line=9'>10</a> test_f1s.append(f1_module(preds, y).item())
#
# File ~/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# /home/mmsamiei/symbolic-world/parity.ipynb Cell 5' in MySimpleModel.forward(self, x, clss)
#      <a href='vscode-notebook-cell://ssh-remote%2B192.168.198.96/home/mmsamiei/symbolic-world/parity.ipynb#ch0000003vscode-remote?line=24'>25</a> clss_embedding = self.clss_embedding(clss)
#      <a href='vscode-notebook-cell://ssh-remote%2B192.168.198.96/home/mmsamiei/symbolic-world/parity.ipynb#ch0000003vscode-remote?line=25'>26</a> temp = torch.cat((clss_embedding, temp), dim=1)
# ---> <a href='vscode-notebook-cell://ssh-remote%2B192.168.198.96/home/mmsamiei/symbolic-world/parity.ipynb#ch0000003vscode-remote?line=26'>27</a> temp = self.transformer_layer(temp)
#      <a href='vscode-notebook-cell://ssh-remote%2B192.168.198.96/home/mmsamiei/symbolic-world/parity.ipynb#ch0000003vscode-remote?line=27'>28</a> temp = temp[:, 0, :]
#      <a href='vscode-notebook-cell://ssh-remote%2B192.168.198.96/home/mmsamiei/symbolic-world/parity.ipynb#ch0000003vscode-remote?line=28'>29</a> temp = self.fc1(temp)
#
# File ~/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/venv/lib/python3.8/site-packages/torch/nn/modules/transformer.py:198, in TransformerEncoder.forward(self, src, mask, src_key_padding_mask)
#     195 output = src
#     197 for mod in self.layers:
# --> 198     output = mod(output, src_mask=mask, src_key_padding_mask=src_key_padding_mask)
#     200 if self.norm is not None:
#     201     output = self.norm(output)
#
# File ~/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/venv/lib/python3.8/site-packages/torch/nn/modules/transformer.py:339, in TransformerEncoderLayer.forward(self, src, src_mask, src_key_padding_mask)
#     337     x = x + self._ff_block(self.norm2(x))
#     338 else:
# --> 339     x = self.norm1(x + self._sa_block(x, src_mask, src_key_padding_mask))
#     340     x = self.norm2(x + self._ff_block(x))
#     342 return x
#
# File ~/venv/lib/python3.8/site-packages/torch/nn/modules/transformer.py:347, in TransformerEncoderLayer._sa_block(self, x, attn_mask, key_padding_mask)
#     345 def _sa_block(self, x: Tensor,
#     346               attn_mask: Optional[Tensor], key_padding_mask: Optional[Tensor]) -> Tensor:
# --> 347     x = self.self_attn(x, x, x,
#     348                        attn_mask=attn_mask,
#     349                        key_padding_mask=key_padding_mask,
#     350                        need_weights=False)[0]
#     351     return self.dropout1(x)
#
# File ~/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/venv/lib/python3.8/site-packages/torch/nn/modules/activation.py:1003, in MultiheadAttention.forward(self, query, key, value, key_padding_mask, need_weights, attn_mask)
#     992     attn_output, attn_output_weights = F.multi_head_attention_forward(
#     993         query, key, value, self.embed_dim, self.num_heads,
#     994         self.in_proj_weight, self.in_proj_bias,
#    (...)
#    1000         q_proj_weight=self.q_proj_weight, k_proj_weight=self.k_proj_weight,
#    1001         v_proj_weight=self.v_proj_weight)
#    1002 else:
# -> 1003     attn_output, attn_output_weights = F.multi_head_attention_forward(
#    1004         query, key, value, self.embed_dim, self.num_heads,
#    1005         self.in_proj_weight, self.in_proj_bias,
#    1006         self.bias_k, self.bias_v, self.add_zero_attn,
#    1007         self.dropout, self.out_proj.weight, self.out_proj.bias,
#    1008         training=self.training,
#    1009         key_padding_mask=key_padding_mask, need_weights=need_weights,
#    1010         attn_mask=attn_mask)
#    1011 if self.batch_first:
#    1012     return attn_output.transpose(1, 0), attn_output_weights
#
# File ~/venv/lib/python3.8/site-packages/torch/nn/functional.py:5102, in multi_head_attention_forward(query, key, value, embed_dim_to_check, num_heads, in_proj_weight, in_proj_bias, bias_k, bias_v, add_zero_attn, dropout_p, out_proj_weight, out_proj_bias, training, key_padding_mask, need_weights, attn_mask, use_separate_proj_weight, q_proj_weight, k_proj_weight, v_proj_weight, static_k, static_v)
#    5098 #
#    5099 # (deep breath) calculate attention and out projection
#    5100 #
#    5101 attn_output, attn_output_weights = _scaled_dot_product_attention(q, k, v, attn_mask, dropout_p)
# -> 5102 attn_output = attn_output.transpose(0, 1).contiguous().view(tgt_len, bsz, embed_dim)
#    5103 attn_output = linear(attn_output, out_proj_weight, out_proj_bias)
#    5105 if need_weights:
#    5106     # average attention weights over heads
#
# KeyboardInterrupt:

# %%
a = model_config.copy()
a['b']=  0

# %%
a
# Out:
# {'d_model': 32,
#  'dim_feedforward': 64,
#  'n_head': 8,
#  'num_layers': 1,
#  'num_obj': 8,
#  'a': 0,
#  'b': 0}
