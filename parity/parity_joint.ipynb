# %%
import torch
from torch.utils.data import Dataset, IterableDataset, DataLoader
import torch.nn as nn
import random
import numpy as np
import math
from tqdm.auto import tqdm
import torchmetrics

# %%
experiment_config = {
    'obj_size': 2,
    'obs_size': 8,
}
model_config = {
    'd_model': 32,
    'n_head': 2,
    'num_layers': 2,
    'num_obj': 8,
}
training_config = {
    'batch_size':1024,
    'lr': 5e-5,
    'max_step': 10000
}

# %%
device = torch.device('cuda')

# %%
class SymbolicWorldIterableDataset(IterableDataset):

    def __init__(self, num_objects, observation_size):
        self.num_objects = num_objects
        self.observation_size = observation_size
        pass

    def generate_observation(self):
        observation = torch.randint(0, self.num_objects, (self.observation_size,))

        parity_1 = ((observation == 1).sum())%2
        return {'observation':observation, 'parity_1':parity_1}

    def __iter__(self):
        while(True):
            yield self.generate_observation()

iterable_dataset = SymbolicWorldIterableDataset(experiment_config['obj_size'], 8)
loader1 = DataLoader(iterable_dataset, batch_size=training_config['batch_size'])
iterable_dataset2 = SymbolicWorldIterableDataset(experiment_config['obj_size'], 4)
loader2 = DataLoader(iterable_dataset2, batch_size=training_config['batch_size'])

test_loaders_list = []
for observation_size in [4,8,16,32,64]:
    test_loader_name = f'observation_size_{observation_size}'
    test_loader_data = DataLoader(SymbolicWorldIterableDataset(experiment_config['obj_size'], observation_size),\
        batch_size=training_config['batch_size'])
    test_loaders_list.append({
        'name': test_loader_name,
        'data_loader': test_loader_data
    })

if True:
    for a in loader1:
        print(a['observation'][0])
        print(a['parity_1'][0])
        break
# Out:
# tensor([1, 1, 1, 1, 0, 1, 0, 0])
# tensor(1)

# %%
class MySimpleModel(nn.Module):
    
    def __init__(self, model_config):
        super(MySimpleModel, self).__init__()
        d_model = model_config['d_model']
        n_heads = model_config['n_head']
        n_layers = model_config['num_layers']
        n_objects = model_config['num_obj']
        n_clss = 5
        self.d_model = d_model
        self.encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=n_heads, batch_first=True)
        self.transformer_layer = torch.nn.TransformerEncoder(self.encoder_layer, n_layers)
        self.token_embedding = torch.nn.Embedding(n_objects, d_model)
        self.clss_embedding = torch.nn.Embedding(n_clss, d_model)
        self.fc1 = torch.nn.Linear(d_model, 2)
        
    def forward(self, x, clss):
        '''
        x : long tensor: [batch, seq_len]
        clss: long tensor: [batch, 1]
        return: tensor: [batch, 2]
        '''
        temp = x
        temp = self.token_embedding(temp)
        clss_embedding = self.clss_embedding(clss)
        temp = torch.cat((clss_embedding, temp), dim=1)
        temp = self.transformer_layer(temp)
        temp = temp[:, 0, :]
        temp = self.fc1(temp)
        return temp

# %%
model = MySimpleModel(
model_config).to(device)
loss_module = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=training_config['lr'])
f1_module = torchmetrics.F1Score(num_classes=2).to(device)

# %%
def eval(test_loader):
    with torch.no_grad():
            test_f1s = []
            for j, batch in enumerate(test_loader):
                x = batch['observation'].to(device)
                clss = torch.ones((x.shape[0], 1)).long().to(device)
                y = batch['parity_1'].to(device)
                output = model(x, clss)
                preds = output.argmax(dim=1)
                test_f1s.append(f1_module(preds, y).item())
                if j > 10:
                    break
            f1 = sum(test_f1s)/len(test_f1s)
            return round(f1, 4)

# %%
dataiter1 = iter(loader1)
dataiter2 = iter(loader2)

loss_history = []
max_steps = training_config['max_step']
log_every_steps = 200
for i in tqdm(range(max_steps)):
    if i % 1 == 0:
        batch = dataiter1.next()
    else:
        batch = dataiter2.next()
    x = batch['observation'].to(device)
    clss = torch.ones((x.shape[0], 1)).long().to(device)
    y = batch['parity_1'].to(device)
    optimizer.zero_grad()
    output = model(x, clss)
    loss = loss_module(output, y)
    loss_history.append(loss.item())
    loss.backward()
    optimizer.step()
    if i > max_steps:
        break
    if i % log_every_steps == 0 :
        print("step {}".format(i))
        print("loss: {:.2e}".format(sum(loss_history)/len(loss_history)))
        loss_history = []
        train_f1 = f1_module(output.argmax(dim=1), y).item()
        print('train f1: ', round(train_f1,4))
        for test_loader in test_loaders_list:
            test_acc = eval(test_loader['data_loader'])
            print(test_loader['name'], " f1_score: " , test_acc)
        print('------------------------')
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# step 0
# loss: 7.07e-01
# train f1:  0.5156
# observation_size_4  f1_score:  0.5063
# observation_size_8  f1_score:  0.498
# observation_size_16  f1_score:  0.5036
# observation_size_32  f1_score:  0.4989
# observation_size_64  f1_score:  0.503
# ------------------------
# step 200
# loss: 6.95e-01
# train f1:  0.501
# observation_size_4  f1_score:  0.5141
# observation_size_8  f1_score:  0.505
# observation_size_16  f1_score:  0.4899
# observation_size_32  f1_score:  0.501
# observation_size_64  f1_score:  0.5037
# ------------------------
# step 400
# loss: 6.91e-01
# train f1:  0.668
# observation_size_4  f1_score:  0.6044
# observation_size_8  f1_score:  0.65
# observation_size_16  f1_score:  0.5208
# observation_size_32  f1_score:  0.5043
# observation_size_64  f1_score:  0.4915
# ------------------------
# step 600
# loss: 3.60e-01
# train f1:  0.9805
# observation_size_4  f1_score:  0.3866
# observation_size_8  f1_score:  0.975
# observation_size_16  f1_score:  0.4447
# observation_size_32  f1_score:  0.5062
# observation_size_64  f1_score:  0.5006
# ------------------------
# step 800
# loss: 9.19e-02
# train f1:  0.9873
# observation_size_4  f1_score:  0.3748
# observation_size_8  f1_score:  0.988
# observation_size_16  f1_score:  0.5061
# observation_size_32  f1_score:  0.4779
# observation_size_64  f1_score:  0.5064
# ------------------------
# step 1000
# loss: 5.40e-02
# train f1:  0.9893
# observation_size_4  f1_score:  0.3816
# observation_size_8  f1_score:  0.9903
# observation_size_16  f1_score:  0.4845
# observation_size_32  f1_score:  0.4975
# observation_size_64  f1_score:  0.5034
# ------------------------
# step 1200
# loss: 3.45e-02
# train f1:  0.9971
# observation_size_4  f1_score:  0.4373
# observation_size_8  f1_score:  0.9951
# observation_size_16  f1_score:  0.4727
# observation_size_32  f1_score:  0.511
# observation_size_64  f1_score:  0.4985
# ------------------------
# step 1400
# loss: 1.94e-02
# train f1:  0.998
# observation_size_4  f1_score:  0.4811
# observation_size_8  f1_score:  0.9982
# observation_size_16  f1_score:  0.495
# observation_size_32  f1_score:  0.4934
# observation_size_64  f1_score:  0.4956
# ------------------------
# step 1600
# loss: 1.25e-02
# train f1:  0.9971
# observation_size_4  f1_score:  0.5041
# observation_size_8  f1_score:  0.9985
# observation_size_16  f1_score:  0.5148
# observation_size_32  f1_score:  0.4806
# observation_size_64  f1_score:  0.5092
# ------------------------
# step 1800
# loss: 9.97e-03
# train f1:  0.9922
# observation_size_4  f1_score:  0.4887
# observation_size_8  f1_score:  0.9989
# observation_size_16  f1_score:  0.4843
# observation_size_32  f1_score:  0.49
# observation_size_64  f1_score:  0.5019
# ------------------------
# step 2000
# loss: 8.07e-03
# train f1:  0.999
# observation_size_4  f1_score:  0.4965
# observation_size_8  f1_score:  0.9989
# observation_size_16  f1_score:  0.5042
# observation_size_32  f1_score:  0.4823
# observation_size_64  f1_score:  0.4866
# ------------------------
# step 2200
# loss: 6.88e-03
# train f1:  1.0
# observation_size_4  f1_score:  0.4932
# observation_size_8  f1_score:  0.9993
# observation_size_16  f1_score:  0.5306
# observation_size_32  f1_score:  0.4627
# observation_size_64  f1_score:  0.498
# ------------------------
# step 2400
# loss: 5.85e-03
# train f1:  1.0
# observation_size_4  f1_score:  0.4925
# observation_size_8  f1_score:  0.9993
# observation_size_16  f1_score:  0.4916
# observation_size_32  f1_score:  0.4835
# observation_size_64  f1_score:  0.5022
# ------------------------
# step 2600
# loss: 5.08e-03
# train f1:  0.9961
# observation_size_4  f1_score:  0.5074
# observation_size_8  f1_score:  0.9993
# observation_size_16  f1_score:  0.4862
# observation_size_32  f1_score:  0.4926
# observation_size_64  f1_score:  0.4849
# ------------------------
# step 2800
# loss: 4.91e-03
# train f1:  1.0
# observation_size_4  f1_score:  0.4977
# observation_size_8  f1_score:  0.9994
# observation_size_16  f1_score:  0.4813
# observation_size_32  f1_score:  0.4934
# observation_size_64  f1_score:  0.4902
# ------------------------
# step 3000
# loss: 3.89e-03
# train f1:  1.0
# observation_size_4  f1_score:  0.5066
# observation_size_8  f1_score:  0.9993
# observation_size_16  f1_score:  0.4985
# observation_size_32  f1_score:  0.4836
# observation_size_64  f1_score:  0.4909
# ------------------------
# step 3200
# loss: 3.83e-03
# train f1:  0.998
# observation_size_4  f1_score:  0.5048
# observation_size_8  f1_score:  0.9996
# observation_size_16  f1_score:  0.5129
# observation_size_32  f1_score:  0.4842
# observation_size_64  f1_score:  0.5003
# ------------------------
# step 3400
# loss: 3.63e-03
# train f1:  1.0
# observation_size_4  f1_score:  0.498
# observation_size_8  f1_score:  0.9996
# observation_size_16  f1_score:  0.5096
# observation_size_32  f1_score:  0.4637
# observation_size_64  f1_score:  0.4801
# ------------------------
# step 3600
# loss: 3.38e-03
# train f1:  1.0
# observation_size_4  f1_score:  0.5003
# observation_size_8  f1_score:  0.9994
# observation_size_16  f1_score:  0.5015
# observation_size_32  f1_score:  0.4808
# observation_size_64  f1_score:  0.4946
# ------------------------
# step 3800
# loss: 2.79e-03
# train f1:  1.0
# observation_size_4  f1_score:  0.4942
# observation_size_8  f1_score:  0.9998
# observation_size_16  f1_score:  0.5221
# observation_size_32  f1_score:  0.4633
# observation_size_64  f1_score:  0.4854
# ------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/mmsamiei/symbolic-world/parity/parity_joint.ipynb Cell 8' in <cell line: 7>()
#      <a href='vscode-notebook-cell://ssh-remote%2B192.168.198.96/home/mmsamiei/symbolic-world/parity/parity_joint.ipynb#ch0000007vscode-remote?line=15'>16</a> output = model(x, clss)
#      <a href='vscode-notebook-cell://ssh-remote%2B192.168.198.96/home/mmsamiei/symbolic-world/parity/parity_joint.ipynb#ch0000007vscode-remote?line=16'>17</a> loss = loss_module(output, y)
# ---> <a href='vscode-notebook-cell://ssh-remote%2B192.168.198.96/home/mmsamiei/symbolic-world/parity/parity_joint.ipynb#ch0000007vscode-remote?line=17'>18</a> loss_history.append(loss.item())
#      <a href='vscode-notebook-cell://ssh-remote%2B192.168.198.96/home/mmsamiei/symbolic-world/parity/parity_joint.ipynb#ch0000007vscode-remote?line=18'>19</a> loss.backward()
#      <a href='vscode-notebook-cell://ssh-remote%2B192.168.198.96/home/mmsamiei/symbolic-world/parity/parity_joint.ipynb#ch0000007vscode-remote?line=19'>20</a> optimizer.step()
#
# KeyboardInterrupt:
